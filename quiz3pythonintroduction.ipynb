# %% [markdown]
# <a href="https://colab.research.google.com/github/laryxo/python-programming/blob/main/quiz3pythonintroduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intro to Python Programming QUIZ 3

# %%
# Q1: Which is the command you type at the prompt 
# to find version of installed Python program

# Answer:   python --version

# Q2: Find output of below code snippet

ints = set([1,1,2,3,3,3,4])

print("Answer to Q2: ", len(ints))
print('')

# Q3: Find output of below code

def test1(param):
    return param

def test2(param):
    return param * 2

def test3(param):
    return param + 3

result = test1(test2(test3(1)))

print("Answer to Q3: ", result)
print('')

# Q4: Describe output of this code

testArr = [11,22,33,22,11]
result = testArr[0] #initializing

for iter in testArr:
    if iter > result:
        result = iter
print("Answer to Q4: ", result)
print('')

# Q5: Find the output of below code

mylist = ['a','aa','aaa','b','bb','bbb']

print("Answer to Q5: ", mylist[int(-1/2)])
print('')

# Q6 Creating an instance of Ubuntu class

class Ubuntu:
    pass 
"""This is a docstring. I have created a new class"""

# Python class names are written in CapitalizedWords notation by convention.
# E.g. A class for a German Shepard dog breed is written as GermanShepard 
# pass keyword is used as a placeholder indicating where the code will 
# eventually go, to avoid errors


# Creating an instance of class Dog (showing correct way of class instantiation)
class Dog:
    # Class attribute
    species = "Canis familiaris"
    def __init__(self, name, breed, color, age):
	    # Instance attribute
        self.name = name
        self.breed = breed
        self.color = color
        self.age = age

# Q7 Correct syntax to output Hello World

print("Answer to Q7: " + "Hello World")
print('')

# Q8 Show the code output

mylist = ['a','aa','aaa','b','bb','bbb']

print("Answer to Q8: ", mylist[:-1])
print('')

# Q9 Determine the output of the below Python code fragment

var1 = True
var2 = False
var3 = False


if var1 or var2 and var3:
    print("Answer to Q9: " + "True")
else:
    print("Answer to Q9: " + "False")

print('') 

# Q10 How do you insert COMMENTS in Python Code?

# Answer = using the hash [#] symbol

# Q11 Legal variable name convention?

   # must start with a letter or the underscore character.
   # cannot start with a number.
   #can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
   # are case-sensitive (age, Age and AGE are three different variables)

# Q12 Find output of below instructions

def test1(param):
    return str(param)

def test2(param):
    return str(2 * param)

result = test1(1) + test2(2) #concatenates two string parameters

print("Answer to Q12: ", result)
print('')

# Q13 Find output of this code

def test():
    try:
        return 1
    finally:
        return 2
result = test()
print("Answer to Q13: ", result)            
print('')

# Q14 Show correct output of the call to this code

print("Answer to Q14: ", list("hello"))
print('')

# Q15 Identify a KeyError exception

d = {'a': 0, 'b': 1, 'c': 0 }

if d ['a'] > 0:
    print('Answer to Q15: ' + 'ok')

elif d ['b'] > 0:
    print('Answer to Q15: ' + 'ok')

elif d ['c'] > 0:
    print('Answer to Q15: ' + 'ok') 


elif d ['d'] > 0:
    print('Answer to Q15: ' + 'ok')

else:
    print('Answer to Q15: ' + 'not ok')

print('')

# Q16 Creating a variable with a numeric value 5

x = 5

print("Answer to Q16: " + 'x')
print('')

# Q17 Identify valid if/else statement

x = 12
y = 7

if x < y :
    print("Answer to Q17: " + 'foo')
else:
    print("Answer to Q17: " + 'bar')    

print('')

# Q18 Control Structures in a Python program

"Directs the order of execution of the statements in the program"

# Q19 What is the value of this expression

'a' + 'x' if '123'.isdigit() else 'y' + 'b' 

"""The value is:  'ax'  """

# Q20 What signifies the end of a statement block or suite in Python?

"A line that is indented less than the previous line"

# Q21 What is the correct syntax to output the type of a variable
# or object in Python?

"print(type(x))"

# Q22 What is the correct way to create a function in Python?

"def myFunction():"

# Q23 In Python, 'Hello', is the same as "Hello" ?

"True"

print('')
# Q24 What is the output of the following code snippet:

print("Answer to Q24: ")
if 'bar' in {'foo': 1, 'bar': 2, 'baz': 3 }:
    print(1)
    print(2)
    if 'a' in 'qux':
        print(3)
print(4)        

print('')

# Q25 Which of the following is the output of the below piece of code?

import random
print("Answer to Q25: ", random.seed(3))

print('')

# Q26 Which of the following is the output of the instructions given below?

mylist = [1, 5, 9, int(0)]
print("Answer to Q26: ", sum(mylist))

print('')

# Q27 Which of the following is the output 
# of the Python code fragment given below?

var1 = 4.5
var2 = 2
print("Answer to Q27: ", var1//var2)

print('')

# Q28 Which of the following is the output of the below Python code?

def myfunc():
    try:
        print('Monday')
    finally:
        print('Tuesday')
myfunc()            

print('')

# Q29 Which of the following is the output of the below Python code?

var1 = lambda var: var * 2
ret = lambda var: var * 3
result = 2 
result = var1(result)
result = ret(result)
result = var1(result)

print("Answer to Q29: ", result)

print('')

# Q30 What is the output of the following code snippet:

print("Answer to Q30: ")

if 'bar' in {'foo': 1, 'bar': 2, 'baz': 3 }:
    print(1)
    print(2)
    if 'a' in 'qux':
        print(3)
print(4)
# Out:
# Answer to Q2:  4
#
# Answer to Q3:  8
#
# Answer to Q4:  33
#
# Answer to Q5:  a
#
# Answer to Q7: Hello World
#
# Answer to Q8:  ['a', 'aa', 'aaa', 'b', 'bb']
#
# Answer to Q9: True
#
# Answer to Q12:  14
#
# Answer to Q13:  2
#
# Answer to Q14:  ['h', 'e', 'l', 'l', 'o']
#
# Answer to Q15: ok
#
# Answer to Q16: x
#
# Answer to Q17: bar
#
#
# Answer to Q24:
# 1
# 2
# 4
#
# Answer to Q25:  None
#
# Answer to Q26:  15
#
# Answer to Q27:  2.0
#
# Monday
# Tuesday
#
# Answer to Q29:  24
#
# Answer to Q30:
# 1
# 2
# 4
